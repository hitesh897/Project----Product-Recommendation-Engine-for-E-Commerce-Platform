# %%
#Importing the required libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the Dataset

Ratings = pd.read_csv(r"C:\Users\Hp\Desktop\p3\DataSet.csv")
Ratings
# Out:
#                 USERID   PRODUCTID  RATING   TIMESTAMP  \
# 0        AKM1MP6P0OYPR   132793040       5  1365811200
# 1       A2CX7LUOHB2NDG   321732944       5  1341100800
# 2       A2NWSAGRHCP8N5   439886341       1  1367193600
# 3       A2WNBOD3WNDNKT   439886341       3  1374451200
# 4       A1GI0U4ZRJA8WN   439886341       1  1334707200
# ...                ...         ...     ...         ...
# 119995  A196105BWLP8XW  B00005T3FU       4  1166572800
# 119996  A2QH58H5QF47LG  B00005T3FX       4  1365724800
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5  1340841600
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5  1335916800
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4  1357948800
#
#                                                      Link
# 0       https://www.amazon.in/Robustrion-Flexible-Sams...
# 1       https://www.amazon.in/Astronomical-Telescope-R...
# 2       https://www.amazon.in/charging-Samsung-Origina...
# 3       https://www.amazon.in/charging-Samsung-Origina...
# ...

# %%
#Shape of the Dataset

Ratings.shape
# Out:
# (120000, 5)

# %%
#Extracting a general summary of the Dataset using info() function

Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   USERID     120000 non-null  object
#  1   PRODUCTID  120000 non-null  object
#  2   RATING     120000 non-null  int64
#  3   TIMESTAMP  120000 non-null  int64
#  4   Link       120000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 4.6+ MB

# %%
#Generating the Descriptive statistics of the Dataset by using describe() function.
Ratings.describe()
# Out:
#               RATING     TIMESTAMP
# count  120000.000000  1.200000e+05
# mean        4.034392  1.198743e+09
# std         1.353400  1.601853e+08
# min         1.000000  9.127296e+08
# 25%         4.000000  1.019758e+09
# 50%         5.000000  1.231718e+09
# 75%         5.000000  1.358554e+09
# max         5.000000  1.405987e+09

# %%
#Finding the datatypes of the columns
Ratings.dtypes
# Out:
# USERID       object
# PRODUCTID    object
# RATING        int64
# TIMESTAMP     int64
# Link         object
# dtype: object

# %%
#Loading the Dataset with Links updated and sorted according to the productID's and also taken only 120000 rows as the original ones is huge.

df = pd.read_csv(r"C:\Users\Hp\Desktop\p3\DataSet.csv")
df
# Out:
#                 USERID   PRODUCTID  RATING   TIMESTAMP  \
# 0        AKM1MP6P0OYPR   132793040       5  1365811200
# 1       A2CX7LUOHB2NDG   321732944       5  1341100800
# 2       A2NWSAGRHCP8N5   439886341       1  1367193600
# 3       A2WNBOD3WNDNKT   439886341       3  1374451200
# 4       A1GI0U4ZRJA8WN   439886341       1  1334707200
# ...                ...         ...     ...         ...
# 119995  A196105BWLP8XW  B00005T3FU       4  1166572800
# 119996  A2QH58H5QF47LG  B00005T3FX       4  1365724800
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5  1340841600
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5  1335916800
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4  1357948800
#
#                                                      Link
# 0       https://www.amazon.in/Robustrion-Flexible-Sams...
# 1       https://www.amazon.in/Astronomical-Telescope-R...
# 2       https://www.amazon.in/charging-Samsung-Origina...
# 3       https://www.amazon.in/charging-Samsung-Origina...
# ...

# %%
#Creating a copy of the original Dataset
dfcopy=df.copy()
dfcopy
# Out:
#                 USERID   PRODUCTID  RATING   TIMESTAMP  \
# 0        AKM1MP6P0OYPR   132793040       5  1365811200
# 1       A2CX7LUOHB2NDG   321732944       5  1341100800
# 2       A2NWSAGRHCP8N5   439886341       1  1367193600
# 3       A2WNBOD3WNDNKT   439886341       3  1374451200
# 4       A1GI0U4ZRJA8WN   439886341       1  1334707200
# ...                ...         ...     ...         ...
# 119995  A196105BWLP8XW  B00005T3FU       4  1166572800
# 119996  A2QH58H5QF47LG  B00005T3FX       4  1365724800
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5  1340841600
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5  1335916800
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4  1357948800
#
#                                                      Link
# 0       https://www.amazon.in/Robustrion-Flexible-Sams...
# 1       https://www.amazon.in/Astronomical-Telescope-R...
# 2       https://www.amazon.in/charging-Samsung-Origina...
# 3       https://www.amazon.in/charging-Samsung-Origina...
# ...

# %%
#The first five columns of the dataset
df.head()
# Out:
#            USERID  PRODUCTID  RATING   TIMESTAMP  \
# 0   AKM1MP6P0OYPR  132793040       5  1365811200
# 1  A2CX7LUOHB2NDG  321732944       5  1341100800
# 2  A2NWSAGRHCP8N5  439886341       1  1367193600
# 3  A2WNBOD3WNDNKT  439886341       3  1374451200
# 4  A1GI0U4ZRJA8WN  439886341       1  1334707200
#
#                                                 Link
# 0  https://www.amazon.in/Robustrion-Flexible-Sams...
# 1  https://www.amazon.in/Astronomical-Telescope-R...
# 2  https://www.amazon.in/charging-Samsung-Origina...
# 3  https://www.amazon.in/charging-Samsung-Origina...
# 4  https://www.amazon.in/charging-Samsung-Origina...

# %%
#The last five columns of the dataset
df.tail()
# Out:
#                 USERID   PRODUCTID  RATING   TIMESTAMP  \
# 119995  A196105BWLP8XW  B00005T3FU       4  1166572800
# 119996  A2QH58H5QF47LG  B00005T3FX       4  1365724800
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5  1340841600
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5  1335916800
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4  1357948800
#
#                                                      Link
# 119995  https://www.amazon.com/American-Plating-501G-T...
# 119996  https://www.amazon.com/American-Plating-511TG-...
# 119997  https://www.amazon.com/American-Plating-511TG-...
# 119998  https://www.amazon.com/American-Plating-511TG-...
# 119999  https://www.amazon.com/American-Plating-511TG-...

# %%
#Finding if there are any null values in the dataset 

df.isnull().sum() #there are no null values in the data
# Out:
# USERID       0
# PRODUCTID    0
# RATING       0
# TIMESTAMP    0
# Link         0
# dtype: int64

# %%
#Finding the datatypes 

df.dtypes
# Out:
# USERID       object
# PRODUCTID    object
# RATING        int64
# TIMESTAMP     int64
# Link         object
# dtype: object

# %%
#Finding the shape of the dataset

#Taken only 120000 rows for the model because the original one is too huge.
df.shape #It is
# Out:
# (120000, 5)

# %%
#Descriptive statistics of the Dataset
df.describe()
# Out:
#               RATING     TIMESTAMP
# count  120000.000000  1.200000e+05
# mean        4.034392  1.198743e+09
# std         1.353400  1.601853e+08
# min         1.000000  9.127296e+08
# 25%         4.000000  1.019758e+09
# 50%         5.000000  1.231718e+09
# 75%         5.000000  1.358554e+09
# max         5.000000  1.405987e+09

# %%
#Dropping the timestamp column as it is not required for the model building 
df2 = df.drop("TIMESTAMP", axis='columns')
df2
# Out:
#                 USERID   PRODUCTID  RATING  \
# 0        AKM1MP6P0OYPR   132793040       5
# 1       A2CX7LUOHB2NDG   321732944       5
# 2       A2NWSAGRHCP8N5   439886341       1
# 3       A2WNBOD3WNDNKT   439886341       3
# 4       A1GI0U4ZRJA8WN   439886341       1
# ...                ...         ...     ...
# 119995  A196105BWLP8XW  B00005T3FU       4
# 119996  A2QH58H5QF47LG  B00005T3FX       4
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4
#
#                                                      Link
# 0       https://www.amazon.in/Robustrion-Flexible-Sams...
# 1       https://www.amazon.in/Astronomical-Telescope-R...
# 2       https://www.amazon.in/charging-Samsung-Origina...
# 3       https://www.amazon.in/charging-Samsung-Origina...
# 4       https://www.amazon.in/charging-Samsung-Origina...
# ...                                                   ...
# ...

# %%
#General summary of the dataset.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   USERID     120000 non-null  object
#  1   PRODUCTID  120000 non-null  object
#  2   RATING     120000 non-null  int64
#  3   Link       120000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ MB

# %%
#Finding the datatypes of the columns
df2.dtypes
# Out:
# USERID       object
# PRODUCTID    object
# RATING        int64
# Link         object
# dtype: object

# %%
#Finding if there are any null values

df2.isnull().sum() #There are no null values in the Dataset.
# Out:
# USERID       0
# PRODUCTID    0
# RATING       0
# Link         0
# dtype: int64

# %%
df2
# Out:
#                 USERID   PRODUCTID  RATING  \
# 0        AKM1MP6P0OYPR   132793040       5
# 1       A2CX7LUOHB2NDG   321732944       5
# 2       A2NWSAGRHCP8N5   439886341       1
# 3       A2WNBOD3WNDNKT   439886341       3
# 4       A1GI0U4ZRJA8WN   439886341       1
# ...                ...         ...     ...
# 119995  A196105BWLP8XW  B00005T3FU       4
# 119996  A2QH58H5QF47LG  B00005T3FX       4
# 119997  A3IVS4YSQILKJ0  B00005T3FX       5
# 119998  A3CX0PA6OMS2W3  B00005T3FX       5
# 119999   AG2W9OHJJYRHJ  B00005T3FX       4
#
#                                                      Link
# 0       https://www.amazon.in/Robustrion-Flexible-Sams...
# 1       https://www.amazon.in/Astronomical-Telescope-R...
# 2       https://www.amazon.in/charging-Samsung-Origina...
# 3       https://www.amazon.in/charging-Samsung-Origina...
# 4       https://www.amazon.in/charging-Samsung-Origina...
# ...                                                   ...
# ...

# %%
df2['RATING'].unique()
# Out:
# array([5, 1, 3, 2, 4], dtype=int64)

# %%
print(df2.isnull().sum())
colours = ['Red', 'Green'] 
sns.heatmap(df2.isnull(),cmap=sns.color_palette(colours))


#Green is non-null and Red is null
#There are no null values in the Dataset(its red below Zero)
# Out:
# USERID       0
# PRODUCTID    0
# RATING       0
# Link         0
# dtype: int64
# <AxesSubplot:>

# %%
df2[df2.duplicated()] #There are no duplicated records present in the Dataset
# Out:
# Empty DataFrame
# Columns: [USERID, PRODUCTID, RATING, Link]
# Index: []

# %%
#Histogram of the Ratings column in the Dataset
df2.hist(column='RATING', grid=True, edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'RATING'}>]], dtype=object)

# %%
#PieChart

plt.figure(figsize=(18,10))
#myexplode = [0.2, 0, 0, 0, 0]
plt.pie(df2['RATING'].value_counts()[:15],labels =df2['RATING'].value_counts()[:15].index, startangle = 360, shadow = True, autopct='%1.2f%%')
plt.title("Pie Chart for Ratings")
plt.show()


#From the Piechart we can interpret that there are 55.06% of Five star ratings

# %%
#Countplot for the Ratings column

plt.figure(figsize=(16,8))
sns.countplot('RATING',data=df2)
plt.xticks(rotation=None)
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (20, 12))
sns.set(style = "darkgrid")
ax = sns.countplot(y = 'RATING', data = df2, palette=("cool_r"),
              order = df2['RATING'].value_counts().index)
for p in ax.patches:
    ax.annotate(int(p.get_width()), ((p.get_x() + p.get_width()), p.get_y()), xytext = (-3, -21),
                fontsize = 20, color = '#004d00', textcoords = 'offset points', horizontalalignment = 'right')
plt.title('RATINGS')
plt.show()

# %%
# Number of unique user id  in the data
print('Number of unique users in Raw data = ', df2['USERID'].nunique())

# Number of unique product id  in the data
print('Number of unique product in Raw data = ',df2['PRODUCTID'].nunique())
# Out:
# Number of unique users in Raw data =  106877
# Number of unique product in Raw data =  8103

# %%
#Checking the top 10 users based on number of times ratings are given.

mostly_rated=df2.groupby('USERID').size().sort_values(ascending=False)[:10]
print('Top 10 users based on ratings: \n',mostly_rated)
# Out:
# Top 10 users based on ratings:
#  USERID
# A231WM2Z2JL0U3    134
# A2BGZ52M908MJY     54
# A1RPTVW5VEOSI      37
# AY8Q1X7G96HV5      37
# A1MJMYLRTZ76ZX     36
# A7Y6AVS576M03      33
# A1NVD0TKNS1GT5     30
# A3MEIR72XKQY88     28
# A6FIAB28IS79       28
# AT2J7H5TRZM8Z      27
# dtype: int64

# %%
counts=df2.USERID.value_counts()
df3=df2[df2.USERID.isin(counts[counts>=15].index)]

# %%
#Splitting the Data
from sklearn.model_selection import train_test_split

#Split the data randomnly into train and test datasets into 70:30 ratio
train_data, test_data = train_test_split(df2, test_size = 0.3, random_state=0)
train_data.head()
# Out:
#                USERID   PRODUCTID  RATING  \
# 89228  A3M6NSETKKDCUV  B00005AB9R       4
# 82588    ADA4JFNTR47K  B000051ZOA       5
# 67061   APO9VO28EXKW3  B00004Z5M1       1
# 62895  A3UWDEBSKQFM7V  B00004Y7ZP       4
# 57885  A1X6S5SZVCZ5HH  B00004WCGF       5
#
#                                                     Link
# 89228  https://www.amazon.com/5014104-Hollister-Two-p...
# 82588  https://www.amazon.com/%C3%9CTest-Sensitive-In...
# 67061  https://www.amazon.com/2019-cargador-Sonicare-...
# 62895  https://www.amazon.com/Babo-Botanicals-Essenti...
# 57885  https://www.amazon.com/11090-3-U-Bolt-Sytle-Ca...

# %%
print('Shape of training data: ',train_data.shape)
print('Shape of testing data: ',test_data.shape)
# Out:
# Shape of training data:  (84000, 4)
# Shape of testing data:  (36000, 4)

# %% [markdown]
# COLLABORATIVE FILTERING RECOMMENDER MODEL

# %%
Amazon_products = pd.concat([train_data, test_data]).reset_index()
Amazon_products.head()
# Out:
#    index          USERID   PRODUCTID  RATING  \
# 0  89228  A3M6NSETKKDCUV  B00005AB9R       4
# 1  82588    ADA4JFNTR47K  B000051ZOA       5
# 2  67061   APO9VO28EXKW3  B00004Z5M1       1
# 3  62895  A3UWDEBSKQFM7V  B00004Y7ZP       4
# 4  57885  A1X6S5SZVCZ5HH  B00004WCGF       5
#
#                                                 Link
# 0  https://www.amazon.com/5014104-Hollister-Two-p...
# 1  https://www.amazon.com/%C3%9CTest-Sensitive-In...
# 2  https://www.amazon.com/2019-cargador-Sonicare-...
# 3  https://www.amazon.com/Babo-Botanicals-Essenti...
# 4  https://www.amazon.com/11090-3-U-Bolt-Sytle-Ca...

# %%
#Taking the first 10000 entries as sample Dataframe
Amazon_ratings = df2.head(10000)

# %%
#Creating a pivot table
ratings_matrix = Amazon_ratings.pivot_table(values='RATING', index='USERID', columns=['PRODUCTID','Link'], fill_value=0)
ratings_matrix.head()
# Out:
# PRODUCTID                                                                                                                                                                                                                                                                        059400232X  \
# Link                  https://www.amazon.in/ESR-Trifold-Sleep-Lightweight-Ascend/dp/B09B2D68R8/ref=sr_1_9575?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159297&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9575
# USERID
# A00766851QZZUBOVF4JFT                                                  0
# A01255851ZO1U93P8RKGE                                                  0
# A0293130VTX2ZXA70JQS                                                   0
# A030530627MK66BD8V4LN                                                  0
# A0402564TCEO67AUZFJO                                                   0
#
# ...

# %%
#Shape of the matric created.
ratings_matrix.shape
# Out:
# (9826, 1305)

# %%
#Transposing the matrix 

X = ratings_matrix.T
X.head()
# Out:
# USERID                                                         A00766851QZZUBOVF4JFT  \
# PRODUCTID  Link
# 059400232X https://www.amazon.in/ESR-Trifold-Sleep-Lightwe...                      0
# 089933623X https://www.amazon.in/MSI-Graphics-G102Wired-Bl...                      0
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# 1034385789 https://www.amazon.in/Cable-Xiaomi-Original-Cha...                      0
# 1039869017 https://www.amazon.in/Protect-AppleCare-Service...                      0
#
# USERID                                                         A01255851ZO1U93P8RKGE  \
# PRODUCTID  Link
# 059400232X https://www.amazon.in/ESR-Trifold-Sleep-Lightwe...                      0
# 089933623X https://www.amazon.in/MSI-Graphics-G102Wired-Bl...                      0
# 094339676X https://www.amazon.in/Neoprene-Sleeve-Cover-Mac...                      0
# ...

# %%
#Shape of the matrix after it is transposed.
X.shape
# Out:
# (1305, 9826)

# %%
#Calling a variable 
X1 = X

# %%
#Importing the required libraries.
import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
#Fitting the matrix into the model

SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (1305, 10)

# %%
#Correlation matrix of the matrix which was fit into the model
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (1305, 1305)

# %%
#Checking the 99th row

X.index[99]
# Out:
# ('4293001999',
#  'https://www.amazon.in/CQLEK%C2%AE-Ultimate-Mirror-Mount-Stand/dp/B08R5Y2C9Y/ref=sr_1_5743?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159748&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-5743')

# %%
#It gives the number in the index when an entry is given.

i = ('970407998',
 'https://www.amazon.in/Amazin-Homes-Stylish-Printed-Computer/dp/B09ZPLLJRP/ref=sr_1_9422?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159314&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-9422')
product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 308

# %%
index = np.where(df3.PRODUCTID == 4293001999)
index
# Out:
# (array([], dtype=int64),)

# %%
#Matrix of both the correlation matrix with the product_ID(variable given above)

correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (1305,)

# %%
#Final Recommendations

Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:9]
# Out:
# [('7807284382',
#   'https://www.amazon.in/PANTUM-M6518NW-funtion-Printer-22PPM/dp/B09VGSB218/ref=sr_1_5253?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159808&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-5253'),
#  ('8805001716',
#   'https://www.amazon.in/Red-Lemon-Protective-Notebook-Computer/dp/B09SPKY4BC/ref=sr_1_5194?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159814&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-5194'),
#  ('8862935293',
#   'https://www.amazon.in/0-5mm-Pitch-flexible-ribbon-B-TYPE-150MM/dp/B0953VJVG3/ref=sr_1_5163?crid=2A2RRWHXQP4AH&keywords=electronics&qid=1665159820&qu=eyJxc2MiOiI4LjQ0IiwicXNhIjoiNy45OCIsInFzcCI6IjUuODUifQ%3D%3D&s=electronics&sprefix=ele%2Celectronics%2C215&sr=1-5163'),
#  ('8862936826',
# ...

# %%
#Recommended products as a Dataframe for easy view.

Final_DF = pd.DataFrame(Recommend, columns=['Recommended_product_ID','Recommended_Product_Links'])
Final_DF.head()
# Out:
#   Recommended_product_ID                          Recommended_Product_Links
# 0             7807284382  https://www.amazon.in/PANTUM-M6518NW-funtion-P...
# 1             8805001716  https://www.amazon.in/Red-Lemon-Protective-Not...
# 2             8862935293  https://www.amazon.in/0-5mm-Pitch-flexible-rib...
# 3             8862936826  https://www.amazon.in/AAC01-Shockproof-Protect...
# 4             8956240825  https://www.amazon.in/CROSSVOLT-OnePlus-Chargi...
